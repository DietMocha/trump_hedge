# %%
from bs4 import BeautifulSoup
import requests
import lxml
import urllib

root = 'http://www.fortune.com/'
search = 'fortune500/2019/search/'


def scrape():
    
    r = requests.get(root + search)
    soup = BeautifulSoup(r.content, 'lxml')
    f501 = soup.find("div", class_="rt-tr-group")
    print(f501)
    return f501
	
	
scrape()
# Out:
# None

# %%
r = requests.get(root + search)
soup = BeautifulSoup(r.content, 'lxml')
f501 = soup.find_all("div")
a = []

# %%
soup.find('div', class_='searchResults__cellContent--3WEWj')

# %%
for bit in soup.find_all('div', class_='searchResults__cellContent--3WEWj'):
    print(bit.text)

# %%
<a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/walmart/">
    <div class="searchResults__cellContent--3WEWj">
        <span>
            <div>Walmart</div>
        </span>
    </div>
</a>

# %%
print(a) rt-tr-group
searchResults__cellContent--3WEWj
# Out:
# []

# %%
soup.find('div', class_='rt-tr-group')

# %%
soup.find_all('a', class_='searchResults__cellWrapper--39MAj')
# Out:
# []

# %%
soup.find('div',class_="rt-tr-group")
# Out:
# None

# %%
<div class="rt-tr-group" role="rowgroup">
    <div class="rt-tr -even" role="row">
        <div class="rt-td searchResults__cell--2Y7Ce searchResults__rank--1sTfo" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>2</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce searchResults__title--3LyRA" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>
                        <div>Exxon Mobil</div>
                    </span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>$290,212.0</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>18.8%</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>$20,840.0</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>5.7%</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>$346,196.0</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>$342,172.0</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>-</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>71,000</span>
                </div>
            </a>
        </div>
        <div class="rt-td searchResults__cell--2Y7Ce" role="gridcell" style="flex: 100 0 auto; width: 100px;">
            <a class="searchResults__cellWrapper--39MAj" href="https://fortune.com/fortune500/2019/exxon-mobil/">
                <div class="searchResults__cellContent--3WEWj">
                    <span>-</span>
                </div>
            </a>
        </div>
    </div>
</div>
# Out:
#   File "<ipython-input-44-b4f702ab2f7e>", line 1
#     <div class="rt-tr-group" role="rowgroup">
#     ^
# SyntaxError: invalid syntax

# %%
stocks=urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies%27').read()
soup=BeautifulSoup(stocks, 'lxml')

print(soup.text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-171-a0e63ec54d95> in <module>()
# ----> 1 stocks=urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies%27').read()
#       2 soup=BeautifulSoup(stocks, 'lxml')
#       3
#       4 print(soup.text)
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...

# %%
import bs4 as bs
import urllib

"""s&p500-- https://en.wikipedia3.org/wiki/List_of_S%26P_500_companies"""

stocks=urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies').read()
soup=bs.BeautifulSoup(stocks, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of S&amp;P 500 companies - Wikipedia</title>
# ...

# %%
'''for co in soup.find('tbody').find_all('tr'):
    print(co.find('a').text)
    print(co.find())'''

li_list = soup.find('tbody').find_all('tr')

for li in li_list:
    a = li.find('a')
    co_link = a['href']
    co_name = li.find('')
    print(co_ticker.text, co_link, co_name, '\n')
# Out:
# Symbol https://www.nyse.com/quote/XNYS:ZTS None
#
# MMM https://www.nyse.com/quote/XNYS:ZTS None
#
# ABT https://www.nyse.com/quote/XNYS:ZTS None
#
# ABBV https://www.nyse.com/quote/XNYS:ZTS None
#
# ABMD https://www.nyse.com/quote/XNYS:ZTS None
#
# ACN https://www.nyse.com/quote/XNYS:ZTS None
#
# ATVI https://www.nyse.com/quote/XNYS:ZTS None
#
# ADBE https://www.nyse.com/quote/XNYS:ZTS None
#
# AMD https://www.nyse.com/quote/XNYS:ZTS None
#
# AAP https://www.nyse.com/quote/XNYS:ZTS None
#
# AES https://www.nyse.com/quote/XNYS:ZTS None
#
# AMG https://www.nyse.com/quote/XNYS:ZTS None
#
# AFL https://www.nyse.com/quote/XNYS:ZTS None
#
# A https://www.nyse.com/quote/XNYS:ZTS None
#
# APD https://www.nyse.com/quote/XNYS:ZTS None
#
# AKAM https://www.nyse.com/quote/XNYS:ZTS None
#
# ALK https://www.nyse.com/quote/XNYS:ZTS None
#
# ALB https://www.nyse.com/quote/XNYS:ZTS None
#
# ARE https://www.nyse.com/quote/XNYS:ZTS None
#
# ALXN https://www.nyse.com/quote/XNYS:ZTS None
#
# ...

# %%
li_list = soup.find('tbody').find_all('tr')

for li in li_list:
    for co in li.find:
        co_ticker = co.find('a')
        co_link = co_ticker['href']
        co_name = co.find('a')
        print(co_ticker.text, co_link, co_name, '\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-258-9f33c3b412af> in <module>()
#       2
#       3 for li in li_list:
# ----> 4     for co in li.find:
#       5         co_ticker = co.find('a')
#       6         co_link = co_ticker['href']
#
# TypeError: 'method' object is not iterable

# %%
li_list = soup.find('tbody').find_all('tr')
counter = 0
for li in li_list:
#     add key
#     .setdefault(key, [])
    print(li.text)
    li_dict.setdefault(li, [])
    for co in li.find_all('td'):
        li_dict[li].append(co)
#         add value
print(li_dict)
# Out:
# Symbol
#
# Security
# SEC filings
# GICS Sector
# GICS Sub Industry
# Headquarters Location
# Date first added
# CIK
# Founded
#
#
# MMM
#
# 3M Company
# reports
# Industrials
# Industrial Conglomerates
# St. Paul, Minnesota
#
# 0000066740
# 1902
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-232-dfe62edfedfa> in <module>()
#       7     li_dict.setdefault(li, [])
#       8     for co in li.find_all('td'):
# ----> 9         li_dict[li].append(co)
#      10 #         add value
#      11 print(li_dict)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
li_list = soup.find('tbody').find_all('tr')
counter = 0
for li in li_list:
    print(li)
    li_dict.setdefault(li, [])
    for co in li.find_all('td'):
        print(co.text, counter, '\n')
        counter += 1
# Out:
# <tr>
# <th><a href="/wiki/Symbol" title="Symbol">Symbol</a>
# </th>
# <th>Security</th>
# <th><a href="/wiki/SEC_filing" title="SEC filing">SEC filings</a></th>
# <th><a href="/wiki/Global_Industry_Classification_Standard" title="Global Industry Classification Standard">GICS</a> Sector</th>
# <th>GICS Sub Industry</th>
# <th>Headquarters Location</th>
# <th>Date first added</th>
# <th><a href="/wiki/Central_Index_Key" title="Central Index Key">CIK</a></th>
# <th>Founded
# </th></tr>
# <tr>
# <td><a class="external text" href="https://www.nyse.com/quote/XNYS:MMM" rel="nofollow">MMM</a>
# </td>
# <td><a href="/wiki/3M" title="3M">3M Company</a></td>
# <td><a class="external text" href="https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMM&amp;action=getcompany" rel="nofollow">reports</a></td>
# <td>Industrials</td>
# <td>Industrial Conglomerates</td>
# <td><a class="mw-redirect" href="/wiki/St._Paul,_Minnesota" title="St. Paul, Minnesota">St. Paul, Minnesota</a></td>
# <td></td>
# ...

# %%
li_dict = {}

# %%
li_list = soup.find('tbody').find_all('tr')
counter = 0
for li in li_list:
#     a = li.find('a')
#     key = a.text
#     li_dict.setdefault(key, [])
    for co in li:
        print(co)
#     li_dict.setdefault(li, [])
#     li_dict[li].append()
#     add value
# print(li_dict)
# Out:
# <th><a href="/wiki/Symbol" title="Symbol">Symbol</a>
# </th>
#
#
# <th>Security</th>
#
#
# <th><a href="/wiki/SEC_filing" title="SEC filing">SEC filings</a></th>
#
#
# <th><a href="/wiki/Global_Industry_Classification_Standard" title="Global Industry Classification Standard">GICS</a> Sector</th>
#
#
# <th>GICS Sub Industry</th>
#
#
# <th>Headquarters Location</th>
#
#
# <th>Date first added</th>
#
#
# <th><a href="/wiki/Central_Index_Key" title="Central Index Key">CIK</a></th>
#
#
# <th>Founded
# </th>
#
#
# <td><a class="external text" href="https://www.nyse.com/quote/XNYS:MMM" rel="nofollow">MMM</a>
# </td>
#
#
# <td><a href="/wiki/3M" title="3M">3M Company</a></td>
#
#
# <td><a class="external text" href="https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMM&amp;action=getcompany" rel="nofollow">reports</a></td>
#
#
# <td>Industrials</td>
#
#
# <td>Industrial Conglomerates</td>
#
#
# ...

# %%
print(li_dict)
# Out:
# {'Symbol': [], 'MMM': [], 'ABT': [], 'ABBV': [], 'ABMD': [], 'ACN': [], 'ATVI': [], 'ADBE': [], 'AMD': [], 'AAP': [], 'AES': [], 'AMG': [], 'AFL': [], 'A': [], 'APD': [], 'AKAM': [], 'ALK': [], 'ALB': [], 'ARE': [], 'ALXN': [], 'ALGN': [], 'ALLE': [], 'AGN': [], 'ADS': [], 'LNT': [], 'ALL': [], 'GOOGL': [], 'GOOG': [], 'MO': [], 'AMZN': [], 'AMCR': [], 'AEE': [], 'AAL': [], 'AEP': [], 'AXP': [], 'AIG': [], 'AMT': [], 'AWK': [], 'AMP': [], 'ABC': [], 'AME': [], 'AMGN': [], 'APH': [], 'ADI': [], 'ANSS': [], 'ANTM': [], 'AON': [], 'AOS': [], 'APA': [], 'AIV': [], 'AAPL': [], 'AMAT': [], 'APTV': [], 'ADM': [], 'ARNC': [], 'ANET': [], 'AJG': [], 'AIZ': [], 'ATO': [], 'T': [], 'ADSK': [], 'ADP': [], 'AZO': [], 'AVB': [], 'AVY': [], 'BKR': [], 'BLL': [], 'BAC': [], 'BK': [], 'BAX': [], 'BBT': [], 'BDX': [], 'BRK.B': [], 'BBY': [], 'BIIB': [], 'BLK': [], 'HRB': [], 'BA': [], 'BKNG': [], 'BWA': [], 'BXP': [], 'BSX': [], 'BMY': [], 'AVGO': [], 'BR': [], 'BF.B': [], 'CHRW': [], 'COG': [], 'CDNS
# ...
